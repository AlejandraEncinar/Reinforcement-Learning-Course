# %% [markdown]
# <div class="alert alert-block alert-info">
#    <h2 align="center"> <center><b> Reinforcement Learning Assignment 2 - Value Iteration </b></center></h2>
#
# <br>
# <center><font size="3">This notebook is a part of teaching material for ELEC-E8125</font></center>
# <center><font size="3">Sep 4, 2023 - Nov 30, 2023</font></center>
# <center><font size="3">Aalto University</font></center>
# </div>
#
#
# <a id='TOC'></a>
#
# <div class="alert alert-block alert-success">
#
# # Table of contents
# * <a href='#1.'> 1. Introduction </a>
# * <a href='#1.1'> 1.1 Learning Objectives </a>
# * <a href='#1.2'> 1.2 Code Structure & Files </a>
# * <a href='#2.'> 2. Sailor Gridworld </a>
# * <a href='#3.'> 3. Value Iteration </a>
# * <a href='#4.'> 4. Submitting </a>
# * <a href='#4.1'> 4.1 Feedback </a>
# * <a href='#5.'> References</a>
#
#
# <a href='#T1'><b>Student Task 1.</b> Implementing Value Iteration (30 points) </a>\
# <a href='#Q1'><b>Student Question 1.1</b> Reinforcement Learning Components (5 points) </a>\
# <a href='#Q2'><b>Student Question 1.2</b> Value Analysis (5 points) </a>\
# <a href='#Q3'><b>Student Question 1.3</b> Investigating Optimal Path (5 points) </a>\
# <a href='#T2'><b>Student Task 2.</b> Investigating Convergence Properties (15 points) </a>\
# <a href='#T3'><b>Student Task 3.</b> Number of Iterations Until Convergence (5 points) </a>\
# <a href='#T4'><b>Student Task 4.</b> Evaluating the Policy (10 points) </a>\
# <a href='#Q4'><b>Student Question 4.1</b> Relationship Between Discounted Return and the Value Function (10 points)</a>\
# <a href='#Q5'><b>Student Question 4.2</b> Considering Unknown Environments (15 points) </a>
#
#
# **Total Points:** 100

# %% [markdown]
# # 1. Introduction <a id='1.'></a>
#
# In this exercise we look at how a simple method like value iteration can be used to find an optimal behaviour for a sailing gridworld environment. We further investigate the properties of value iteration and how environment definition can affect the behaviour learned by the agent.
#
#
# ## 1.1 Learning Objectives: <a id='1.1'></a>
# - To understand the value iteration method and how it works
# - To understand the importance of environment definition on behaviours
#
#
# ## 1.2 Code Structure & Files <a id='1.2'></a>
#
# You don’t have to edit any other file other than ```ex2.ipynb``` to complete this exercise.
#
# ```
# ├───imgs                 # Images used in notebook
# │   ex2.ipynb            # Main assignment file containing tasks
# │   feedback.ipynb       # Please give feedback in here
# │   sailing.py           # Defines the sailing gridworld environment
# │   utils.py             # Contains save object function
# ```

# %% [markdown]
# # 2. Sailor Gridworld <a id='2.'></a>
#
# Consider a sailor who managed to escape from a sinking ship, and now has to find the way to the nearest harbour. The sea is divided into a grid, with each grid cell corresponding to a state. Therefore, the state can be thought of as a two dimensional vector:
#
# $$
# s=\left(\begin{array}{c}
# x \\
# y \\
# \end{array}\right)
# $$
#
# There are four actions available: moving left, right, up, and down. When the sailor reaches the harbour, the episode terminates and a reward of 10 is given. If the sailor hits the rocks, the episode terminates and a reward of −2 is given. On all other steps, the reward is 0. The environment is shown in Figure 1.
#
# <figure>
# <img src="imgs/sailor1.png" width="400px">
# <figcaption style="text-align: center"> Figure 1: The Sailor gridworld environment. Light blue squares represent the calm part of the sea, gray squares – the rocks, dark blue – the windy passage between the rocks. The green square in upper right corner is the target harbour. The current (in this picture also the initial) position of the sailor is denoted with a brown "boat"  </figcaption>
# </figure>
#
# The shortest way to the harbour goes through a narrow passage between rocks, which is known to have unpredictable heavy wind conditions. When moving in that area, the sailor can be carried an extra "square" in a random direction — that is, land in any of the squares adjacent to the desired target square. This is shown in Figure 2.
#
# <figure>
# <img src="imgs/sailor2.png" width="700px">
# <figcaption style="text-align: center"> Figure 2: Possible state transitions in windy passage when the issued action was to go left (a) or to go up (b). The sailor may end up in the square to the left (a) or up (b), as indicated by the green arrow. There is also a small $p_{wind}$ that the sailor will move for an additional unit in a random direction, as indicated by one of the yellow arrows. Therefore, in addition to moving one square in the target direction, it can (1) move two squares in the desired direction, (2) stay in place, or (3) be carried sideways to one of the squares on the diagonal. </figcaption>
# </figure>
#
# The sea around the passage is generally calm, but there is a low probability that the sailor will be carried in the direction perpendicular to where he was heading, as shown in Figure 3.
#
# <figure>
# <img src="imgs/sailor3.png" width="300px">
# <figcaption style="text-align: center"> Figure 3: Possible state transitions in calm water when the issued action was to go right. The sailor may end up in the square to the right, as indicated by the green arrow. There is a small chance $p_{calm}$ that the sailor will move in the perpendicular direction, as indicated by the yellow arrows.  </figcaption>
# </figure>
#
# All of these probabilities ($p_{calm}$ and $p_{wind}$) as well as the effects of the wind and the exact location of the harbour are perfectly known to the sailor.

# %% [markdown]
# # 3. Value iteration <a id='3.'></a>
#
# Value iteration is a method for computing an optimal MDP (Markov Decision Process) policy. We start with arbitrary initial state values and iteratively update our estimate of every state’s value by using Bellman equation as an update rule. A more detailed description, along with the exact equations, can be found in [1] Section 4.4.

# %% [markdown]
# <a id='T1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 1.</b> Implementing Value Iteration (30 points) </h3>
#
# Implement value iteration for the sailor using the code below as a template, assuming the discount factor value $\gamma = 0.9$. In addition to the state values, compute the policy – path to the harbour, using computed state values. Run your implementation for 100 iterations. Render the values and policy after every iteration and observe how the values and policy are updated. Also, **run the program a few times and check if the sailor is able to reach the goal every time**. Ensure the values and policy are saved as a ```.pkl``` file using the ```u.save_object()``` cell below . This ```.pkl``` file is saved within the same directory as this file. **Attach an image of the estimated state values and policy into your submission.**
#
# **Hint:** The environment contains a 3-D array (```env.transitions```) of shape $[n_x, n_y, n_a]$, which contains all possible state transitions. The transitions for state $(x, y)$ with action a can be accessed by ```env.transitions [x, y, a]``` . This will return a list of Python ***named-tuples*** Transition=$(next_state, reward, done, prob)$. The components of the named-tuple can be accessed as ```transition.state```, ```transition.reward```, ```transition.done```, ```transition.prob```. For example, ```env.transitions [3, 3, env.UP]``` would return a list of three possible state transitions:
#
# ```
# (state=(3, 2), reward=0.0, done=0.0, prob=0.05),
# (state=(3, 4), reward=0.0, done=0.0, prob=0.05),
# (state=(4, 3), reward=0.0, done=0.0, prob=0.9)
# ```
#
# which corresponds to moving to state (4, 3) with probability 0.9, or moving to states (3, 4) and (3, 2) with probability 0.05 for each. None of these transitions results in a reward or in terminating the episode (the second and third elements are zero). When the episode has already terminated, the next state will be set to ```None```.
#
# **Caveat:** Pay extra attention to indices in the Bellman equation – specifically, where $V_k$ and where $V_{k−1}$ must be used.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
import numpy as np
from itertools import product

from sailing import SailingGridworld
import utils as u

from IPython.display import Image

# %%
# Set up the environment
env = SailingGridworld(rock_penalty=-2, value_update_iter=100)

# %%
def get_values_policy(num_iterations=100, gamma=0.9, eps=1e-4, plot_values=False, filename='values.gif'):
    """
    Args:
        num_iterations: num of iterations to update the value function and policy
        gamma: discount factor used in value iteration
        eps: a tiny constant used to check the convergence of the value function and policy
        plot_values: if True, a GIF will be saved to plot state value functions and policy
        filename: filename of the saved value plot, if plot_value is True.
    Returns:
        updated v_est and policy, both are np.ndarray with shape (env.w, env.h)
    """
    
    # value table V_t, it stores the value at a position (x, y).
    v_est = np.zeros((env.w, env.h)) # env.w, env.h: width and height of the environment shown in Fig 1.
    # policy table pi_t, it stores the current action to take at a position (x, y)
    policy = np.zeros((env.w, env.h))
    
    max_diff_v = eps
    i=0
    #for i in range(num_iterations):
    while max_diff_v >= eps:
        ########## Your code starts here ##########
        # TODO: Task 1, implement value iteration and retrive the resulting policy.
        #       In each iteration, update the state values v_est and policy with new values/policy.
        #       The v_est is updated according to the value iteration formula.
        
        # Create a copy of the current value estimate
        i+=1
        policy_prev = policy.copy()
        v_est_prev = v_est.copy()
        
        # Iterate over all states (x, y) in the environment
        for x in range(env.w):
            for y in range(env.h):
                if not env.terminate[x, y]:
                    # Initialize a list to store the Q-values for each action
                    v_values = []

                    # Iterate over all possible actions
                    for a in range(env.n_actions):
                        transitions = env.transitions[x, y, a]
                        sum_s = 0.0

                        # Calculate the expected value using the Bellman equation
                        for transition in transitions:
                            next_state = transition.state
                            reward = transition.reward
                            prob = transition.prob
                            sum_s+=prob*(reward+gamma*v_est_prev[next_state[0], next_state[1]])
                        
                        v_value=sum_s
                        v_values.append(v_value)

                    # Update the value estimate and policy for the current state
                    v_est[x, y] = max(v_values)
                    policy[x, y] = np.argmax(v_values)
                    
        # TODO: Task 2, check the convergence of the value function and policy.
        #       In each iteration, check the maximal absolute difference in successive v_est/policy,
        #       and compare it with eps, e.g., check the difference between v_est_i and v_est_i-1
        
        ########## Your code starts here ##########
        
        max_diff_v = np.max(np.abs(v_est - v_est_prev))
        if max_diff_v < eps:
            print("The absolute difference {} in successive v_est is less than eps {} for iteration {}".format(max_diff_v, eps, i))
        else:
            print("The absolute difference {} in successive v_est is more than eps {} for iteration {}".format(max_diff_v, eps, i))

        max_diff_p = np.max(np.abs(policy - policy_prev))
        if max_diff_p < eps:
            print("The absolute difference {} in successive policy is less than eps {} for iteration {}".format(max_diff_p, eps, i))
        else:
            print("The absolute difference {} in successive policy is more than eps {} for iteration {}".format(max_diff_p, eps, i))

            
    if plot_values:
        # Call env.record_values_policy function with your estimated state values and policy
        # to produce a GIF of the changing values. In our case, we only record the final state values and policy to save running time.
        # Call env.save_values_policy function to save the recorded GIF to filename.gif
        env.record_values_policy(v_est, policy)
        env.save_values_policy(filename=filename)

    return v_est, policy

# %%
# value iteration -- update value estimation and policy
value_est, policy = get_values_policy(num_iterations=100, gamma=0.9, eps=1e-4, plot_values=True, filename='T1_values.gif')
# Out:
# The absolute difference 9.0 in successive v_est is more than eps 0.0001 for iteration 1
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 1
# The absolute difference 7.695 in successive v_est is more than eps 0.0001 for iteration 2
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 2
# The absolute difference 6.561000000000001 in successive v_est is more than eps 0.0001 for iteration 3
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 3
# The absolute difference 5.609655000000001 in successive v_est is more than eps 0.0001 for iteration 4
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 4
# The absolute difference 4.7949264225000015 in successive v_est is more than eps 0.0001 for iteration 5
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 5
# The absolute difference 4.099662091237501 in successive v_est is more than eps 0.0001 for iteration 6
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 6
# The absolute difference 3.5030318477574385 in successive v_est is more than eps 0.0001 for iteration 7
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 7
# The absolute difference 2.991816831735921 in successive v_est is more than eps 0.0001 for iteration 8
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 8
# The absolute difference 2.5577727893789923 in successive v_est is more than eps 0.0001 for iteration 9
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 9
# The absolute difference 2.186451583582192 in successive v_est is more than eps 0.0001 for iteration 10
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 10
# The absolute difference 1.8687749139387462 in successive v_est is more than eps 0.0001 for iteration 11
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 11
# The absolute difference 1.5973967273297343 in successive v_est is more than eps 0.0001 for iteration 12
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 12
# The absolute difference 1.3657557951279062 in successive v_est is more than eps 0.0001 for iteration 13
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 13
# The absolute difference 1.1676741987538652 in successive v_est is more than eps 0.0001 for iteration 14
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 14
# The absolute difference 0.9982426032908587 in successive v_est is more than eps 0.0001 for iteration 15
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 15
# The absolute difference 0.853288043041223 in successive v_est is more than eps 0.0001 for iteration 16
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 16
# The absolute difference 0.7292490036085385 in successive v_est is more than eps 0.0001 for iteration 17
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 17
# The absolute difference 0.6230866837710133 in successive v_est is more than eps 0.0001 for iteration 18
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 18
# The absolute difference 0.5319137706296418 in successive v_est is more than eps 0.0001 for iteration 19
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 19
# The absolute difference 0.43078518246066944 in successive v_est is more than eps 0.0001 for iteration 20
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 20
# The absolute difference 0.3860859310985376 in successive v_est is more than eps 0.0001 for iteration 21
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 21
# The absolute difference 0.3446232730166561 in successive v_est is more than eps 0.0001 for iteration 22
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 22
# The absolute difference 0.30675000866328855 in successive v_est is more than eps 0.0001 for iteration 23
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 23
# The absolute difference 0.272352988786032 in successive v_est is more than eps 0.0001 for iteration 24
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 24
# The absolute difference 0.18639509172386542 in successive v_est is more than eps 0.0001 for iteration 25
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 25
# The absolute difference 0.11704429753892598 in successive v_est is more than eps 0.0001 for iteration 26
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 26
# The absolute difference 0.08067839279211497 in successive v_est is more than eps 0.0001 for iteration 27
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 27
# The absolute difference 0.0474103133621363 in successive v_est is more than eps 0.0001 for iteration 28
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 28
# The absolute difference 0.03982638790943149 in successive v_est is more than eps 0.0001 for iteration 29
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 29
# The absolute difference 0.03235346450806165 in successive v_est is more than eps 0.0001 for iteration 30
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 30
# The absolute difference 0.013976790499348968 in successive v_est is more than eps 0.0001 for iteration 31
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 31
# The absolute difference 0.011922877178826341 in successive v_est is more than eps 0.0001 for iteration 32
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 32
# The absolute difference 0.004028501470985546 in successive v_est is more than eps 0.0001 for iteration 33
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 33
# The absolute difference 0.0035418379669378552 in successive v_est is more than eps 0.0001 for iteration 34
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 34
# The absolute difference 0.0010281247684423844 in successive v_est is more than eps 0.0001 for iteration 35
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 35
# The absolute difference 0.0008980255514551283 in successive v_est is more than eps 0.0001 for iteration 36
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 36
# The absolute difference 0.0002402706446966718 in successive v_est is more than eps 0.0001 for iteration 37
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 37
# The absolute difference 0.0002122737820032805 in successive v_est is more than eps 0.0001 for iteration 38
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 38
# The absolute difference 5.861920284144784e-05 in successive v_est is less than eps 0.0001 for iteration 39
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 39
# The absolute difference 4.6072825211185275e-05 in successive v_est is less than eps 0.0001 for iteration 40
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 40
# The absolute difference 1.3262294115023998e-05 in successive v_est is less than eps 0.0001 for iteration 41
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 41
# The absolute difference 9.439420651236041e-06 in successive v_est is less than eps 0.0001 for iteration 42
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 42
# The absolute difference 2.8168269673445323e-06 in successive v_est is less than eps 0.0001 for iteration 43
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 43
# The absolute difference 1.8463930823164887e-06 in successive v_est is less than eps 0.0001 for iteration 44
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 44
# The absolute difference 5.686930037995808e-07 in successive v_est is less than eps 0.0001 for iteration 45
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 45
# The absolute difference 3.8997645501748224e-07 in successive v_est is less than eps 0.0001 for iteration 46
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 46
# The absolute difference 1.1311386749479624e-07 in successive v_est is less than eps 0.0001 for iteration 47
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 47
# The absolute difference 8.684236540990042e-08 in successive v_est is less than eps 0.0001 for iteration 48
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 48
# The absolute difference 2.390856868039748e-08 in successive v_est is less than eps 0.0001 for iteration 49
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 49
# The absolute difference 1.8362694143014835e-08 in successive v_est is less than eps 0.0001 for iteration 50
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 50
# The absolute difference 4.840526202087858e-09 in successive v_est is less than eps 0.0001 for iteration 51
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 51
# The absolute difference 3.7199348046357272e-09 in successive v_est is less than eps 0.0001 for iteration 52
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 52
# The absolute difference 9.452080229621629e-10 in successive v_est is less than eps 0.0001 for iteration 53
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 53
# The absolute difference 7.26953275353992e-10 in successive v_est is less than eps 0.0001 for iteration 54
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 54
# The absolute difference 1.7898538207106185e-10 in successive v_est is less than eps 0.0001 for iteration 55
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 55
# The absolute difference 1.3778300722577796e-10 in successive v_est is less than eps 0.0001 for iteration 56
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 56
# The absolute difference 3.301103834729702e-11 in successive v_est is less than eps 0.0001 for iteration 57
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 57
# The absolute difference 2.5437874029421437e-11 in successive v_est is less than eps 0.0001 for iteration 58
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 58
# The absolute difference 6.180167488878396e-12 in successive v_est is less than eps 0.0001 for iteration 59
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 59
# The absolute difference 4.590994251429947e-12 in successive v_est is less than eps 0.0001 for iteration 60
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 60
# The absolute difference 1.1337597527472099e-12 in successive v_est is less than eps 0.0001 for iteration 61
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 61
# The absolute difference 8.122391648157645e-13 in successive v_est is less than eps 0.0001 for iteration 62
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 62
# The absolute difference 2.0383694732117874e-13 in successive v_est is less than eps 0.0001 for iteration 63
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 63
# The absolute difference 1.411093464298574e-13 in successive v_est is less than eps 0.0001 for iteration 64
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 64
# The absolute difference 3.597122599785507e-14 in successive v_est is less than eps 0.0001 for iteration 65
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 65
# The absolute difference 2.4202861936828413e-14 in successive v_est is less than eps 0.0001 for iteration 66
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 66
# The absolute difference 6.217248937900877e-15 in successive v_est is less than eps 0.0001 for iteration 67
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 67
# The absolute difference 4.218847493575595e-15 in successive v_est is less than eps 0.0001 for iteration 68
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 68
# The absolute difference 1.1102230246251565e-15 in successive v_est is less than eps 0.0001 for iteration 69
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 69
# The absolute difference 5.551115123125783e-16 in successive v_est is less than eps 0.0001 for iteration 70
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 70
# The absolute difference 4.440892098500626e-16 in successive v_est is less than eps 0.0001 for iteration 71
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 71
# The absolute difference 1.1102230246251565e-16 in successive v_est is less than eps 0.0001 for iteration 72
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 72
# The absolute difference 1.1102230246251565e-16 in successive v_est is less than eps 0.0001 for iteration 73
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 73
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 74
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 74
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 75
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 75
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 76
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 76
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 77
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 77
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 78
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 78
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 79
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 79
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 80
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 80
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 81
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 81
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 82
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 82
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 83
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 83
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 84
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 84
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 85
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 85
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 86
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 86
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 87
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 87
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 88
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 88
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 89
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 89
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 90
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 90
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 91
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 91
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 92
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 92
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 93
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 93
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 94
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 94
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 95
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 95
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 96
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 96
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 97
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 97
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 98
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 98
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 99
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 99
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 100
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 100

# %%
def eval_policy(policy, N=1, gamma=0.9, render=False, filename='env.gif'):
    """
    Args:
        policy: the policy to evaluate.
        N: number of evaluation episode. 
            e.g., N=10 means the policy is evaluated 10 times.
        gamma: discount factor to calculate the discounted_return.
        render: if True, a GIF of the policy's behavior will be saved.
        filename: filename to save the GIF file.
    Returns:
        mean and stddev of discounted_returns.
    """
    discounted_returns = np.empty((N,))
    # Eval policy
    for ep in range(N):
        state = env.reset()
        done = False
        steps = 0
        discounted_return = 0
        
        while not done:

            ########## You code starts here ##########

            # TODO: Use the policy to take the optimal action (Task 1)
            action = policy[state[0], state[1]]

            # Take a step in the environment
            state, reward, done, _ = env.step(action)

            # TODO: Accumulate discounted return for this episode
            discounted_return += reward * (gamma ** steps)
            steps += 1
            
            ########## You code ends here ##########

            if render:
                env.render(filename=filename)
        # Record the discounted return for         
        discounted_returns[ep] = discounted_return
    
    mean_discounted_returns = np.mean(discounted_returns)
    std_discounted_returns = np.std(discounted_returns)
    
    return mean_discounted_returns, std_discounted_returns

# %%
mean_discounted_returns, std_discounted_returns = eval_policy(policy=policy, N=1, gamma=0.9, render=True, filename='T1_eval.gif')

# %% [markdown]
# To see how the sailboat traverses the gridworld use this cell below to display the created gif:

# %%
display(Image(data=open('T1_eval.gif','rb').read(), format='png'))

# %%
display(Image(data=open('T1_values.gif','rb').read(), format='png'))

# %%
# save value and policy
u.save_object({'value': value_est, 'policy': policy}, './value_policy.pkl')

# %% [markdown]
# <a id='Q1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 1.1</b> Reinforcement Learning Components (5 points) </h3>
#
# What is the agent and the environment in this sailor gridworld?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# In this case, the agent would be the sailor and the enviroment the grid including the sea, rocks harbour and wind conditions

# %% [markdown]
# <a id='Q2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 1.2</b> Value Analysis (5 points) </h3>
#
# What is the state value of the harbour and rock states? Why?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# The state value of those states is 0.0 since if the sailor ends there the episode terminates.

# %% [markdown]
# <a id='Q3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 1.3</b> Investigating Optimal Path (5 points) </h3>
#
# Which path did the sailor choose, the safe path below the rocks, or the dangerous path between the rocks? If you change the reward for hitting the rocks to -10 (that is, make the sailor value life more), does he still choose the same path?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
env = SailingGridworld(rock_penalty=-10, value_update_iter=100) # Set up env
value_est, policy = get_values_policy(num_iterations=100, gamma=0.9, eps=1e-4, plot_values=False) # Run value iteration
mean_discounted_returns, std_discounted_returns = eval_policy(policy=policy, N=1, gamma=0.9, render=True, filename='Q1_3.gif') # Evaluate policy
# Out:
# The absolute difference 9.0 in successive v_est is more than eps 0.0001 for iteration 1
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 1
# The absolute difference 7.695 in successive v_est is more than eps 0.0001 for iteration 2
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 2
# The absolute difference 6.561000000000001 in successive v_est is more than eps 0.0001 for iteration 3
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 3
# The absolute difference 5.609655000000001 in successive v_est is more than eps 0.0001 for iteration 4
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 4
# The absolute difference 4.7949264225000015 in successive v_est is more than eps 0.0001 for iteration 5
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 5
# The absolute difference 4.099662091237501 in successive v_est is more than eps 0.0001 for iteration 6
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 6
# The absolute difference 3.5030318477574385 in successive v_est is more than eps 0.0001 for iteration 7
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 7
# The absolute difference 2.991816831735921 in successive v_est is more than eps 0.0001 for iteration 8
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 8
# The absolute difference 2.5577727893789923 in successive v_est is more than eps 0.0001 for iteration 9
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 9
# The absolute difference 2.186451583582192 in successive v_est is more than eps 0.0001 for iteration 10
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 10
# The absolute difference 1.8687749139387462 in successive v_est is more than eps 0.0001 for iteration 11
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 11
# The absolute difference 1.5969876886849244 in successive v_est is more than eps 0.0001 for iteration 12
# The absolute difference 3.0 in successive policy is more than eps 0.0001 for iteration 12
# The absolute difference 1.365406430564627 in successive v_est is more than eps 0.0001 for iteration 13
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 13
# The absolute difference 1.1672661899576091 in successive v_est is more than eps 0.0001 for iteration 14
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 14
# The absolute difference 0.9976436035958911 in successive v_est is more than eps 0.0001 for iteration 15
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 15
# The absolute difference 0.8523773916359079 in successive v_est is more than eps 0.0001 for iteration 16
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 16
# The absolute difference 0.7279482912723845 in successive v_est is more than eps 0.0001 for iteration 17
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 17
# The absolute difference 0.6213686432219354 in successive v_est is more than eps 0.0001 for iteration 18
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 18
# The absolute difference 0.530093475555447 in successive v_est is more than eps 0.0001 for iteration 19
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 19
# The absolute difference 0.45194881369593953 in successive v_est is more than eps 0.0001 for iteration 20
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 20
# The absolute difference 0.3910051419349949 in successive v_est is more than eps 0.0001 for iteration 21
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 21
# The absolute difference 0.35127605694149305 in successive v_est is more than eps 0.0001 for iteration 22
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 22
# The absolute difference 0.31456255752651874 in successive v_est is more than eps 0.0001 for iteration 23
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 23
# The absolute difference 0.28082946111694834 in successive v_est is more than eps 0.0001 for iteration 24
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 24
# The absolute difference 0.22920387183390634 in successive v_est is more than eps 0.0001 for iteration 25
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 25
# The absolute difference 0.2030764948737945 in successive v_est is more than eps 0.0001 for iteration 26
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 26
# The absolute difference 0.17968345490634513 in successive v_est is more than eps 0.0001 for iteration 27
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 27
# The absolute difference 0.15877699734954592 in successive v_est is more than eps 0.0001 for iteration 28
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 28
# The absolute difference 0.1393397239325798 in successive v_est is more than eps 0.0001 for iteration 29
# The absolute difference 1.0 in successive policy is more than eps 0.0001 for iteration 29
# The absolute difference 0.10865830477995092 in successive v_est is more than eps 0.0001 for iteration 30
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 30
# The absolute difference 0.0938683068427012 in successive v_est is more than eps 0.0001 for iteration 31
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 31
# The absolute difference 0.06798294603107585 in successive v_est is more than eps 0.0001 for iteration 32
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 32
# The absolute difference 0.0443982457016725 in successive v_est is more than eps 0.0001 for iteration 33
# The absolute difference 2.0 in successive policy is more than eps 0.0001 for iteration 33
# The absolute difference 0.030490976983381102 in successive v_est is more than eps 0.0001 for iteration 34
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 34
# The absolute difference 0.016443444152620446 in successive v_est is more than eps 0.0001 for iteration 35
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 35
# The absolute difference 0.010779017273069957 in successive v_est is more than eps 0.0001 for iteration 36
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 36
# The absolute difference 0.005103059918975472 in successive v_est is more than eps 0.0001 for iteration 37
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 37
# The absolute difference 0.0032214025760488596 in successive v_est is more than eps 0.0001 for iteration 38
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 38
# The absolute difference 0.001393133448199968 in successive v_est is more than eps 0.0001 for iteration 39
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 39
# The absolute difference 0.0008537408164658866 in successive v_est is more than eps 0.0001 for iteration 40
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 40
# The absolute difference 0.00034560865082144954 in successive v_est is more than eps 0.0001 for iteration 41
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 41
# The absolute difference 0.00020689206300139595 in successive v_est is more than eps 0.0001 for iteration 42
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 42
# The absolute difference 7.963740117605811e-05 in successive v_est is less than eps 0.0001 for iteration 43
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 43
# The absolute difference 4.6788679752163276e-05 in successive v_est is less than eps 0.0001 for iteration 44
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 44
# The absolute difference 1.7310943233761478e-05 in successive v_est is less than eps 0.0001 for iteration 45
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 45
# The absolute difference 1.0018509185139024e-05 in successive v_est is less than eps 0.0001 for iteration 46
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 46
# The absolute difference 3.5907297994963727e-06 in successive v_est is less than eps 0.0001 for iteration 47
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 47
# The absolute difference 2.0530022848408436e-06 in successive v_est is less than eps 0.0001 for iteration 48
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 48
# The absolute difference 7.169651441429892e-07 in successive v_est is less than eps 0.0001 for iteration 49
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 49
# The absolute difference 4.059163136727051e-07 in successive v_est is less than eps 0.0001 for iteration 50
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 50
# The absolute difference 1.3874108045763833e-07 in successive v_est is less than eps 0.0001 for iteration 51
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 51
# The absolute difference 7.792544398643741e-08 in successive v_est is less than eps 0.0001 for iteration 52
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 52
# The absolute difference 2.615847044529218e-08 in successive v_est is less than eps 0.0001 for iteration 53
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 53
# The absolute difference 1.45971195131267e-08 in successive v_est is less than eps 0.0001 for iteration 54
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 54
# The absolute difference 4.82567169557413e-09 in successive v_est is less than eps 0.0001 for iteration 55
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 55
# The absolute difference 2.678636479291896e-09 in successive v_est is less than eps 0.0001 for iteration 56
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 56
# The absolute difference 8.740217993796762e-10 in successive v_est is less than eps 0.0001 for iteration 57
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 57
# The absolute difference 4.83061979306143e-10 in successive v_est is less than eps 0.0001 for iteration 58
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 58
# The absolute difference 1.5611922865588213e-10 in successive v_est is less than eps 0.0001 for iteration 59
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 59
# The absolute difference 8.646167115600178e-11 in successive v_est is less than eps 0.0001 for iteration 60
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 60
# The absolute difference 2.7850555195385596e-11 in successive v_est is less than eps 0.0001 for iteration 61
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 61
# The absolute difference 1.5481560478036727e-11 in successive v_est is less than eps 0.0001 for iteration 62
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 62
# The absolute difference 4.905520434306254e-12 in successive v_est is less than eps 0.0001 for iteration 63
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 63
# The absolute difference 2.737809978725636e-12 in successive v_est is less than eps 0.0001 for iteration 64
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 64
# The absolute difference 8.545941732052142e-13 in successive v_est is less than eps 0.0001 for iteration 65
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 65
# The absolute difference 4.789502128232925e-13 in successive v_est is less than eps 0.0001 for iteration 66
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 66
# The absolute difference 1.475486399726833e-13 in successive v_est is less than eps 0.0001 for iteration 67
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 67
# The absolute difference 8.337774914934926e-14 in successive v_est is less than eps 0.0001 for iteration 68
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 68
# The absolute difference 2.5091040356528538e-14 in successive v_est is less than eps 0.0001 for iteration 69
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 69
# The absolute difference 1.4654943925052066e-14 in successive v_est is less than eps 0.0001 for iteration 70
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 70
# The absolute difference 4.163336342344337e-15 in successive v_est is less than eps 0.0001 for iteration 71
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 71
# The absolute difference 2.55351295663786e-15 in successive v_est is less than eps 0.0001 for iteration 72
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 72
# The absolute difference 7.216449660063518e-16 in successive v_est is less than eps 0.0001 for iteration 73
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 73
# The absolute difference 6.106226635438361e-16 in successive v_est is less than eps 0.0001 for iteration 74
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 74
# The absolute difference 1.1102230246251565e-16 in successive v_est is less than eps 0.0001 for iteration 75
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 75
# The absolute difference 1.1102230246251565e-16 in successive v_est is less than eps 0.0001 for iteration 76
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 76
# The absolute difference 1.1102230246251565e-16 in successive v_est is less than eps 0.0001 for iteration 77
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 77
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 78
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 78
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 79
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 79
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 80
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 80
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 81
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 81
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 82
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 82
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 83
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 83
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 84
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 84
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 85
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 85
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 86
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 86
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 87
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 87
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 88
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 88
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 89
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 89
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 90
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 90
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 91
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 91
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 92
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 92
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 93
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 93
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 94
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 94
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 95
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 95
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 96
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 96
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 97
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 97
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 98
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 98
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 99
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 99
# The absolute difference 0.0 in successive v_est is less than eps 0.0001 for iteration 100
# The absolute difference 0.0 in successive policy is less than eps 0.0001 for iteration 100

# %%
display(Image(data=open('Q1_3.gif','rb').read(), format='png'))

# %% [markdown]
# With the initial rock penalty value the sailor chooses the dangerous path in between the rocks. However, if we change this reward value to -10 the sailor chooses the path below the rocks to avoid the risk of hitting them.

# %% [markdown]
# <a id='T2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 2.</b> Investigating Convergence Properties (15 points) </h3>
#
# What happens if you run the algorithm for 30 iterations? Do the value function and policy still converge? For the value function, you can assume they have converged
# if the maximum change in value is lower than a certain threshold $\epsilon = 10^{-4}$:
# $$
# \max _s\left|V_k(s)-V_{k-1}(s)\right|<\epsilon
# $$
#
# where $V_k(s)$ is the estimated value of state $s$ in $k$-th iteration of the algorithm.
# Generally, **which of them** - the policy or value function - needs less iterations to converge, if any? **Justify your answer**.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
env = SailingGridworld(rock_penalty=-10, value_update_iter=30) # Set up env
value_est, policy = get_values_policy(num_iterations=30, gamma=0.9, eps=10e-4, plot_values=False) # Run value iteration
# Out:
# The absolute difference 9.0 in successive v_est is more than eps 0.001 for iteration 0
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 0
# The absolute difference 7.695 in successive v_est is more than eps 0.001 for iteration 1
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 1
# The absolute difference 6.561000000000001 in successive v_est is more than eps 0.001 for iteration 2
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 2
# The absolute difference 5.609655000000001 in successive v_est is more than eps 0.001 for iteration 3
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 3
# The absolute difference 4.7949264225000015 in successive v_est is more than eps 0.001 for iteration 4
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 4
# The absolute difference 4.099662091237501 in successive v_est is more than eps 0.001 for iteration 5
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 5
# The absolute difference 3.5030318477574385 in successive v_est is more than eps 0.001 for iteration 6
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 6
# The absolute difference 2.991816831735921 in successive v_est is more than eps 0.001 for iteration 7
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 7
# The absolute difference 2.5577727893789923 in successive v_est is more than eps 0.001 for iteration 8
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 8
# The absolute difference 2.186451583582192 in successive v_est is more than eps 0.001 for iteration 9
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 9
# The absolute difference 1.8687749139387462 in successive v_est is more than eps 0.001 for iteration 10
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 10
# The absolute difference 1.5969876886849244 in successive v_est is more than eps 0.001 for iteration 11
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 11
# The absolute difference 1.365406430564627 in successive v_est is more than eps 0.001 for iteration 12
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 12
# The absolute difference 1.1672661899576091 in successive v_est is more than eps 0.001 for iteration 13
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 13
# The absolute difference 0.9976436035958911 in successive v_est is more than eps 0.001 for iteration 14
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 14
# The absolute difference 0.8523773916359079 in successive v_est is more than eps 0.001 for iteration 15
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 15
# The absolute difference 0.7279482912723845 in successive v_est is more than eps 0.001 for iteration 16
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 16
# The absolute difference 0.6213686432219354 in successive v_est is more than eps 0.001 for iteration 17
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 17
# The absolute difference 0.530093475555447 in successive v_est is more than eps 0.001 for iteration 18
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 18
# The absolute difference 0.45194881369593953 in successive v_est is more than eps 0.001 for iteration 19
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 19
# The absolute difference 0.3910051419349949 in successive v_est is more than eps 0.001 for iteration 20
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 20
# The absolute difference 0.35127605694149305 in successive v_est is more than eps 0.001 for iteration 21
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 21
# The absolute difference 0.31456255752651874 in successive v_est is more than eps 0.001 for iteration 22
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 22
# The absolute difference 0.28082946111694834 in successive v_est is more than eps 0.001 for iteration 23
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 23
# The absolute difference 0.22920387183390634 in successive v_est is more than eps 0.001 for iteration 24
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 24
# The absolute difference 0.2030764948737945 in successive v_est is more than eps 0.001 for iteration 25
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 25
# The absolute difference 0.17968345490634513 in successive v_est is more than eps 0.001 for iteration 26
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 26
# The absolute difference 0.15877699734954592 in successive v_est is more than eps 0.001 for iteration 27
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 27
# The absolute difference 0.1393397239325798 in successive v_est is more than eps 0.001 for iteration 28
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 28
# The absolute difference 0.10865830477995092 in successive v_est is more than eps 0.001 for iteration 29
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 29

# %% [markdown]
# The value function does not converge since the max absolute difference at the 30 iteration is 0.10865830477995092 which is greater than eps. However, the absolute difference between consecutive policies tends to 0. Therefore, the policy needs less iterations to converge.

# %% [markdown]
# <a id='T3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 3.</b> Number of Iterations Until Convergence (5 points) </h3>
#
# Set the reward for crashing into the rocks back to -2. Change the termination condition of your algorithm to make it run until convergence. **Report the number of iterations required for the value function to converge.**
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
env = SailingGridworld(rock_penalty=-2, value_update_iter=100) # Set up env
value_est, policy = get_values_policy(num_iterations=100, gamma=0.9, eps=10e-4, plot_values=False) # Run value iteration
# Out:
# The absolute difference 9.0 in successive v_est is more than eps 0.001 for iteration 1
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 1
# The absolute difference 7.695 in successive v_est is more than eps 0.001 for iteration 2
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 2
# The absolute difference 6.561000000000001 in successive v_est is more than eps 0.001 for iteration 3
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 3
# The absolute difference 5.609655000000001 in successive v_est is more than eps 0.001 for iteration 4
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 4
# The absolute difference 4.7949264225000015 in successive v_est is more than eps 0.001 for iteration 5
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 5
# The absolute difference 4.099662091237501 in successive v_est is more than eps 0.001 for iteration 6
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 6
# The absolute difference 3.5030318477574385 in successive v_est is more than eps 0.001 for iteration 7
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 7
# The absolute difference 2.991816831735921 in successive v_est is more than eps 0.001 for iteration 8
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 8
# The absolute difference 2.5577727893789923 in successive v_est is more than eps 0.001 for iteration 9
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 9
# The absolute difference 2.186451583582192 in successive v_est is more than eps 0.001 for iteration 10
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 10
# The absolute difference 1.8687749139387462 in successive v_est is more than eps 0.001 for iteration 11
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 11
# The absolute difference 1.5973967273297343 in successive v_est is more than eps 0.001 for iteration 12
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 12
# The absolute difference 1.3657557951279062 in successive v_est is more than eps 0.001 for iteration 13
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 13
# The absolute difference 1.1676741987538652 in successive v_est is more than eps 0.001 for iteration 14
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 14
# The absolute difference 0.9982426032908587 in successive v_est is more than eps 0.001 for iteration 15
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 15
# The absolute difference 0.853288043041223 in successive v_est is more than eps 0.001 for iteration 16
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 16
# The absolute difference 0.7292490036085385 in successive v_est is more than eps 0.001 for iteration 17
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 17
# The absolute difference 0.6230866837710133 in successive v_est is more than eps 0.001 for iteration 18
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 18
# The absolute difference 0.5319137706296418 in successive v_est is more than eps 0.001 for iteration 19
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 19
# The absolute difference 0.43078518246066944 in successive v_est is more than eps 0.001 for iteration 20
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 20
# The absolute difference 0.3860859310985376 in successive v_est is more than eps 0.001 for iteration 21
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 21
# The absolute difference 0.3446232730166561 in successive v_est is more than eps 0.001 for iteration 22
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 22
# The absolute difference 0.30675000866328855 in successive v_est is more than eps 0.001 for iteration 23
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 23
# The absolute difference 0.272352988786032 in successive v_est is more than eps 0.001 for iteration 24
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 24
# The absolute difference 0.18639509172386542 in successive v_est is more than eps 0.001 for iteration 25
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 25
# The absolute difference 0.11704429753892598 in successive v_est is more than eps 0.001 for iteration 26
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 26
# The absolute difference 0.08067839279211497 in successive v_est is more than eps 0.001 for iteration 27
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 27
# The absolute difference 0.0474103133621363 in successive v_est is more than eps 0.001 for iteration 28
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 28
# The absolute difference 0.03982638790943149 in successive v_est is more than eps 0.001 for iteration 29
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 29
# The absolute difference 0.03235346450806165 in successive v_est is more than eps 0.001 for iteration 30
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 30
# The absolute difference 0.013976790499348968 in successive v_est is more than eps 0.001 for iteration 31
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 31
# The absolute difference 0.011922877178826341 in successive v_est is more than eps 0.001 for iteration 32
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 32
# The absolute difference 0.004028501470985546 in successive v_est is more than eps 0.001 for iteration 33
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 33
# The absolute difference 0.0035418379669378552 in successive v_est is more than eps 0.001 for iteration 34
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 34
# The absolute difference 0.0010281247684423844 in successive v_est is more than eps 0.001 for iteration 35
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 35
# The absolute difference 0.0008980255514551283 in successive v_est is less than eps 0.001 for iteration 36
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 36

# %% [markdown]
# 36 iterations were needed

# %% [markdown]
# <a id='T4'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 4.</b> Evaluating the Policy (10 points) </h3>
#
# Evaluate your learned policy for N = 800 episodes, and compute the discounted return of the initial state, see [1] Eq. (3.8), for each episode. The reward for crashing into rocks must be kept at -2 for this exercise. **Report the average and standard deviation of the initial state’s discounted return over the N=800 episodes.**
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
env = SailingGridworld(rock_penalty=-2, value_update_iter=100) # Set up env
value_est, policy = get_values_policy(num_iterations=100, gamma=0.9, eps=10e-4, plot_values=False) # Run value iteration
mean_discounted_returns, std_discounted_returns = eval_policy(policy=policy, N=800, gamma=0.9)
print("The average is {} and standard deviation {}".format(mean_discounted_returns, std_discounted_returns))
# Out:
# The absolute difference 9.0 in successive v_est is more than eps 0.001 for iteration 1
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 1
# The absolute difference 7.695 in successive v_est is more than eps 0.001 for iteration 2
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 2
# The absolute difference 6.561000000000001 in successive v_est is more than eps 0.001 for iteration 3
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 3
# The absolute difference 5.609655000000001 in successive v_est is more than eps 0.001 for iteration 4
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 4
# The absolute difference 4.7949264225000015 in successive v_est is more than eps 0.001 for iteration 5
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 5
# The absolute difference 4.099662091237501 in successive v_est is more than eps 0.001 for iteration 6
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 6
# The absolute difference 3.5030318477574385 in successive v_est is more than eps 0.001 for iteration 7
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 7
# The absolute difference 2.991816831735921 in successive v_est is more than eps 0.001 for iteration 8
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 8
# The absolute difference 2.5577727893789923 in successive v_est is more than eps 0.001 for iteration 9
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 9
# The absolute difference 2.186451583582192 in successive v_est is more than eps 0.001 for iteration 10
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 10
# The absolute difference 1.8687749139387462 in successive v_est is more than eps 0.001 for iteration 11
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 11
# The absolute difference 1.5973967273297343 in successive v_est is more than eps 0.001 for iteration 12
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 12
# The absolute difference 1.3657557951279062 in successive v_est is more than eps 0.001 for iteration 13
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 13
# The absolute difference 1.1676741987538652 in successive v_est is more than eps 0.001 for iteration 14
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 14
# The absolute difference 0.9982426032908587 in successive v_est is more than eps 0.001 for iteration 15
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 15
# The absolute difference 0.853288043041223 in successive v_est is more than eps 0.001 for iteration 16
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 16
# The absolute difference 0.7292490036085385 in successive v_est is more than eps 0.001 for iteration 17
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 17
# The absolute difference 0.6230866837710133 in successive v_est is more than eps 0.001 for iteration 18
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 18
# The absolute difference 0.5319137706296418 in successive v_est is more than eps 0.001 for iteration 19
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 19
# The absolute difference 0.43078518246066944 in successive v_est is more than eps 0.001 for iteration 20
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 20
# The absolute difference 0.3860859310985376 in successive v_est is more than eps 0.001 for iteration 21
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 21
# The absolute difference 0.3446232730166561 in successive v_est is more than eps 0.001 for iteration 22
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 22
# The absolute difference 0.30675000866328855 in successive v_est is more than eps 0.001 for iteration 23
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 23
# The absolute difference 0.272352988786032 in successive v_est is more than eps 0.001 for iteration 24
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 24
# The absolute difference 0.18639509172386542 in successive v_est is more than eps 0.001 for iteration 25
# The absolute difference 2.0 in successive policy is more than eps 0.001 for iteration 25
# The absolute difference 0.11704429753892598 in successive v_est is more than eps 0.001 for iteration 26
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 26
# The absolute difference 0.08067839279211497 in successive v_est is more than eps 0.001 for iteration 27
# The absolute difference 3.0 in successive policy is more than eps 0.001 for iteration 27
# The absolute difference 0.0474103133621363 in successive v_est is more than eps 0.001 for iteration 28
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 28
# The absolute difference 0.03982638790943149 in successive v_est is more than eps 0.001 for iteration 29
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 29
# The absolute difference 0.03235346450806165 in successive v_est is more than eps 0.001 for iteration 30
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 30
# The absolute difference 0.013976790499348968 in successive v_est is more than eps 0.001 for iteration 31
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 31
# The absolute difference 0.011922877178826341 in successive v_est is more than eps 0.001 for iteration 32
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 32
# The absolute difference 0.004028501470985546 in successive v_est is more than eps 0.001 for iteration 33
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 33
# The absolute difference 0.0035418379669378552 in successive v_est is more than eps 0.001 for iteration 34
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 34
# The absolute difference 0.0010281247684423844 in successive v_est is more than eps 0.001 for iteration 35
# The absolute difference 1.0 in successive policy is more than eps 0.001 for iteration 35
# The absolute difference 0.0008980255514551283 in successive v_est is less than eps 0.001 for iteration 36
# The absolute difference 0.0 in successive policy is less than eps 0.001 for iteration 36
# The average is 0.6606667473811353 and standard deviation 1.3414077667543711

# %% [markdown]
# The average is 0.7007040225244048 and standard deviation 1.3461064220406065

# %% [markdown]
# <a id='Q4'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.1</b> Relationship Between Discounted Return and the Value Function (10 points) </h3>
#
# What is the relationship between the discounted return and the value function? Explain briefly.
#
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# In essence, the value function provides a summary of the expected future returns for each state using probability, while the discounted return represents the actual cumulative reward an agent obtains when following a policy.

# %% [markdown]
# <a id='Q5'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.2</b> Considering Unknown Environments (15 points) </h3>
#
# Imagine a reinforcement learning problem involving a robot exploring an ***unknown*** environment. Could the ***value iteration*** **approach used in this exercise** be applied **directly** to that problem? Why/why not? Which assumptions are unrealistic, if any?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# This model is not directly applicable to a robot exploring an unknown environment for several reasons. First, the model assumes that the agent possesses a model of how the environment responds to its actions, which is not the case for the robot exploring an unknown environment—it lacks a pre-existing model. Secondly, the model was designed with finite state and action spaces in mind, whereas a robot exploring an unknown environment may encounter continuous or significantly larger state and action spaces. Additionally, the assumption of static environment conditions in the model doesn't hold for real-world scenarios where the environment can change over time. Thirdly, the model relies on the Markov Decision Process (MDP) framework, assuming that the current state contains all the necessary information for decision-making. Lastly, Value Iteration, as used in the model, does not explicitly address exploration strategies, whereas in real-world scenarios, effective exploration strategies are vital for uncovering the dynamics and rewards of the environment.

# %% [markdown]
# # 4. Submitting <a id='4.'></a>
# Ensure all tasks and questions (in ```ex2.ipynb```) are answered and the relevant plots are recorded in the relevant places. Details about attaching images and figures can be found below. The relevant graphs to be included for this assignment are:
# - Task 1, image of estimated state values
#
# Ensure the correct model files are saved:
# - Task1, ensure ```value_policy.pkl``` file for the state values and the policy in Task 1 are included.

# %% [markdown]
# ## 4.1 Feedback <a id='4.1'></a>
# In order to help the staff of the course as well as the forthcoming students, it would be great if you could answer feedback questionnaire in ```feedback.ipynb```

# %% [markdown]
# Please use the following section to record references.
# # References <a id='5.'></a>
#
# [1] Sutton R S, Barto A G. Reinforcement learning: An introduction[M]. MIT press, 2018.
